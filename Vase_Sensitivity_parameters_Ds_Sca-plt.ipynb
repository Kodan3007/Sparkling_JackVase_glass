# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# Scatter Plot for Vase Sensitivity Parameters

# %%
def vase_sensitivity_scatter():
    # Parameters (sample aesthetic-engineering data)
    parameters = [
        'Surface Smoothness', 'Thermal Conductivity', 'Tactile Response Time',
        'Optical Feedback', 'Fracture Stress', 'Impact Energy', 
        'Elastic Recovery', 'Thermal Shock Tolerance'
    ]

# %%
  # Touch sensitivity (in %)

# %%
 touch_sensitivity = np.array([91, 88, 86, 90, 0, 0, 0, 0])

# %%
   # Break sensitivity (in %)

# %%
break_sensitivity = np.array([0, 0, 0, 0, 35, 38, 40, 34])

# %%
    # Touch–Break Harmony Ratio (for color scale)

# %%
     harmony_ratio = np.divide(
        np.where(break_sensitivity == 0, np.nan, touch_sensitivity), 
        np.where(break_sensitivity == 0, np.nan, break_sensitivity)
    )

# %%
# Create Scatter Plot

# %%
    plt.figure(figsize=(9,6))

# %%
  plt.scatter(
        touch_sensitivity[touch_sensitivity>0], 
        break_sensitivity[break_sensitivity>0], 
        c=harmony_ratio[~np.isnan(harmony_ratio)], 
        s=790, alpha=0.7, cmap='Set3', edgecolors='yellow'
    )

# %%
# Thus this the Glass_Vase_Sensitivity_Value_Analysis thro' "Scatter plot" did for my crushed heart
